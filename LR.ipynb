# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # import the csv file in R/Python

# %%
Data= pd.read_csv('Admission_Predict.csv')

# %%
Data
# Out:
#      Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0             1        337          118                  4  4.5   4.5  9.65
# 1             2        324          107                  4  4.0   4.5  8.87
# 2             3        316          104                  3  3.0   3.5  8.00
# 3             4        322          110                  3  3.5   2.5  8.67
# 4             5        314          103                  2  2.0   3.0  8.21
# ..          ...        ...          ...                ...  ...   ...   ...
# 395         396        324          110                  3  3.5   3.5  9.04
# 396         397        325          107                  3  3.0   3.5  9.11
# 397         398        330          116                  4  5.0   4.5  9.45
# 398         399        312          103                  3  3.5   4.0  8.78
# 399         400        333          117                  4  5.0   4.0  9.66
#
#      Research  Admit
# 0           1   0.92
# ...

# %% [markdown]
# - print the column names.

# %%
Data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR ', 'CGPA', 'Research', 'Admit'],
#       dtype='object')

# %% [markdown]
# # print the number of rows and number of columns.

# %%
Data.shape
# Out:
# (400, 9)

# %%
Data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR  CGPA  \
# 0           1        337          118                  4  4.5  4.5  9.65
# 1           2        324          107                  4  4.0  4.5  8.87
# 2           3        316          104                  3  3.0  3.5  8.00
# 3           4        322          110                  3  3.5  2.5  8.67
# 4           5        314          103                  2  2.0  3.0  8.21
#
#    Research  Admit
# 0         1   0.92
# 1         1   0.76
# 2         1   0.72
# 3         1   0.80
# 4         0   0.65

# %% [markdown]
# # perform univariate analysis. print boxplot and density plot and give insights into the mean, median, skewness and kurtosis of data.

# %%
sns.boxplot(Data['GRE Score'])
# Out:
# <Axes: >

# %%
Data.mean()
# Out:
# Serial No.           200.500000
# GRE Score            316.807500
# TOEFL Score          107.410000
# University Rating      3.087500
# SOP                    3.400000
# LOR                    3.452500
# CGPA                   8.598925
# Research               0.547500
# Admit                  0.724350
# dtype: float64

# %%
Data.median()
# Out:
# Serial No.           200.50
# GRE Score            317.00
# TOEFL Score          107.00
# University Rating      3.00
# SOP                    3.50
# LOR                    3.50
# CGPA                   8.61
# Research               1.00
# Admit                  0.73
# dtype: float64

# %%
Data.skew()
# Out:
# Serial No.           0.000000
# GRE Score           -0.062893
# TOEFL Score          0.057216
# University Rating    0.171260
# SOP                 -0.275761
# LOR                 -0.106991
# CGPA                -0.065991
# Research            -0.191582
# Admit               -0.353448
# dtype: float64

# %% [markdown]
# It can be seen that the most of the data is left skewed

# %%
Data.kurtosis()
# Out:
# Serial No.          -1.200000
# GRE Score           -0.700489
# TOEFL Score         -0.578778
# University Rating   -0.796287
# SOP                 -0.675610
# LOR                 -0.662484
# CGPA                -0.458476
# Research            -1.973187
# Admit               -0.389126
# dtype: float64

# %%
 Data.columns
# Out:
# Index(['Serial No.', 'GRE Score', 'TOEFL Score', 'University Rating', 'SOP',
#        'LOR', 'CGPA', 'Research', 'Admit'],
#       dtype='object')

# %%
sns.boxplot(Data['GRE Score'], orient= 'h')
# Out:
# <Axes: >

# %%
sns.boxplot(Data['TOEFL Score'], orient= 'h')
# Out:
# <Axes: >

# %%
sns.boxplot(Data['University Rating'], orient='h')
# Out:
# <Axes: >

# %%
sns.boxplot(Data['SOP'], orient= 'h')
# Out:
# <Axes: >

# %%
df= Data.iloc[:,1:9]

# %%
sns.boxplot(Data['LOR'], orient= 'h')

# %%
sns.boxplot(Data['CGPA'], orient= 'h')
# Out:
# <Axes: >

# %%
sns.boxplot(Data['Admit'], orient= 'h')
# Out:
# <Axes: >

# %%
for i in df.columns:
    sns.displot(df[i],kde=True)

# %% [markdown]
# # Print a correlation plot and write inference about the influence of the features on the target variable.

# %%
Data.corr()
# Out:
#                    Serial No.  GRE Score  TOEFL Score  University Rating  \
# Serial No.           1.000000  -0.097526    -0.147932          -0.169948
# GRE Score           -0.097526   1.000000     0.835977           0.668976
# TOEFL Score         -0.147932   0.835977     1.000000           0.695590
# University Rating   -0.169948   0.668976     0.695590           1.000000
# SOP                 -0.166932   0.612831     0.657981           0.734523
# LOR                 -0.088221   0.557555     0.567721           0.660123
# CGPA                -0.045608   0.833060     0.828417           0.746479
# Research            -0.063138   0.580391     0.489858           0.447783
# Admit                0.042336   0.802610     0.791594           0.711250
#
#                         SOP       LOR      CGPA  Research     Admit
# Serial No.        -0.166932 -0.088221 -0.045608 -0.063138  0.042336
# GRE Score          0.612831  0.557555  0.833060  0.580391  0.802610
# ...

# %%
import matplotlib.pyplot as plt


#plt.figure(figsize=())
sns.heatmap(Data.corr(),annot=True,cmap="tab10",square=True,linecolor="w")
# Out:
# <Axes: >

# %% [markdown]
# It can be seen that the GRE Score,CGPA and Tofel are highly Correlated

# %%
sns.pairplot(df)

# %%
Data.head()
# Out:
#    Serial No.  GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# 0           1        337          118                  4  4.5   4.5  9.65
# 1           2        324          107                  4  4.0   4.5  8.87
# 2           3        316          104                  3  3.0   3.5  8.00
# 3           4        322          110                  3  3.5   2.5  8.67
# 4           5        314          103                  2  2.0   3.0  8.21
#
#    Research  Admit
# 0         1   0.92
# 1         1   0.76
# 2         1   0.72
# 3         1   0.80
# 4         0   0.65

# %%
 X1= Data.iloc[:,1]

# %%
X1.mean()
# Out:
# 316.8075

# %%
X1.std()
# Out:
# 11.473646113500475

# %%
X1= (X1-316.8075)/11.473646113500475    #z=(x-mean)/std

# %%
X1.head()
# Out:
# 0    1.759903
# 1    0.626871
# 2   -0.070379
# 3    0.452559
# 4   -0.244691
# Name: GRE Score, dtype: float64

# %%
 X1= pd.DataFrame(X1)

# %%
Y= Data.iloc[:, 8].values

# %% [markdown]
# # Create sample 80:20. Split the data into train and test sets

# %%
from sklearn.model_selection import train_test_split

# %%
X1_train, X1_test, Y1_train, Y1_test = train_test_split(X1,Y, test_size=0.2, random_state=1)

# %% [markdown]
# # create a  simple linear regression model

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(X1_train,Y1_train)
y1_pred=lr.predict(X1_test)

# %% [markdown]
# # print the coeffiecient and intercept

# %%
lr.coef_
# Out:
# array([0.11242164])

# %%
lr.intercept_
# Out:
# 0.7258616720721314

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %% [markdown]
# # create a scatter plot with x and y showing best fit line.

# %%
plt.scatter(X1_test, Y1_test,s = 30)
plt.plot(X1_test, 0.11242164*X1_test+0.7258616720721314)

# %% [markdown]
# # calculate the train and test accuracy

# %%
y1_train_pred=lr.predict(X1_train)
print("MAE: ",mean_absolute_error(Y1_train,y1_train_pred))
print("MSE: ",mean_squared_error(Y1_train,y1_train_pred))
print("r2 score: ",r2_score(Y1_train,y1_train_pred))
# Out:
# MAE:  0.06433139610416286
# MSE:  0.00723641454016921
# r2 score:  0.6300516818551718

# %% [markdown]
# # perform model2 with multiple linear regression

# %%
X= Data.iloc[ :, 1:7].values

# %%
Y= Data.iloc[:, 8].values

# %%
from sklearn.linear_model import LinearRegression

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# - Create sample 80:20
# - Split the data into train and test sets

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, random_state=1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
SC= StandardScaler()

# %%
xtrain = SC.fit(X_train)
xtest = SC.fit_transform(X_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(X_train,Y_train)
y_pred=lr.predict(X_test)

# %% [markdown]
# - print the coeffiecient and intercept

# %%
lr.coef_
# Out:
# array([ 0.0020334 ,  0.00295838,  0.00845054, -0.00408227,  0.02193747,
#         0.11828966])

# %%
lr.intercept_
# Out:
# -1.340611912111282

# %% [markdown]
# - print the model summary .

# %% [markdown]
# # print the model summary .

# %% [markdown]
# # calculate the test accuracy.

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error,r2_score

# %%
y_train_pred=lr.predict(X_train)
print("MAE: ",mean_absolute_error(Y_train,y_train_pred))
print("MSE: ",mean_squared_error(Y_train,y_train_pred))
print("r2 score: ",r2_score(Y_train,y_train_pred))
# Out:
# MAE:  0.04535963575676794
# MSE:  0.004002092399800641
# r2 score:  0.7954004232140318
